# %%
import os
os.getcwd()
# Out:
# '/Users/obadaessa/Desktop/Data Sets'

# %%
#os.chdir('Desktop/Data Sets')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importing data

df = pd.read_csv('Boston.csv')

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
# Outliers with visualization tools

import seaborn as sns
sns.boxplot(x=df['dis'])

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['indus'], df['tax'])
ax.set_xlabel('Propotion of non-retail business acres per town')
ax.set_ylabel('Full-value property-tax rate per $10,000')
plt.show()

# %%
# getting Z score

from scipy import stats
import numpy as np
print(z)
# Out:
# [[0.41978194 0.28482986 1.2879095  ... 0.44105193 1.0755623  0.15968566]
#  [0.41733926 0.48772236 0.59338101 ... 0.44105193 0.49243937 0.10152429]
#  [0.41734159 0.48772236 0.59338101 ... 0.39642699 1.2087274  1.32424667]
#  ...
#  [0.41344658 0.48772236 0.11573841 ... 0.44105193 0.98304761 0.14880191]
#  [0.40776407 0.48772236 0.11573841 ... 0.4032249  0.86530163 0.0579893 ]
#  [0.41500016 0.48772236 0.11573841 ... 0.44105193 0.66905833 1.15724782]]

# %%
# defining threshold to identify outliers

th = 3
print(np.where(z>3))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466]), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
# ...

# %%
print(z[55][2])
# Out:
# 1.4469506858452827

# %%
# Use IQR score

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3-Q1
IQR
# Out:
# crim         3.595037
# zn          12.500000
# indus       12.910000
# chas         0.000000
# nox          0.175000
# rm           0.738000
# age         49.050000
# dis          3.088250
# rad         20.000000
# tax        387.000000
# ptratio      2.800000
# black       20.847500
# lstat       10.005000
# medv         7.975000
# dtype: float64

# %%
print( (df < (Q1 - (1.5*IQR))) | (df < (Q1 + (1.5*IQR))))
# Out:
#      crim    zn  indus   chas   nox     rm   age   dis   rad   tax  ptratio  \
# 0    True  True   True  False  True   True  True  True  True  True     True
# 1    True  True   True  False  True   True  True  True  True  True     True
# 2    True  True   True  False  True  False  True  True  True  True     True
# 3    True  True   True  False  True  False  True  True  True  True     True
# 4    True  True   True  False  True  False  True  True  True  True     True
# ..    ...   ...    ...    ...   ...    ...   ...   ...   ...   ...      ...
# 501  True  True   True  False  True   True  True  True  True  True     True
# 502  True  True   True  False  True   True  True  True  True  True     True
# 503  True  True   True  False  True   True  True  True  True  True     True
# 504  True  True   True  False  True   True  True  True  True  True     True
# 505  True  True   True  False  True   True  True  True  True  True     True
#
#      black  lstat   medv
# 0     True   True   True
# ...

# %%
# Cleaning data by removing outliers 

bostonDfO = df[(z<3).all(axis=1)]
bostonDfO
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
bostonDfO.shape
# Out:
# (415, 14)

# %%
bostonDfOut = df[~((df<(Q1 -1.5*IQR)) | (df >(Q3+1.5*IQR))).any(axis=1)]
bostonDfOut
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...
