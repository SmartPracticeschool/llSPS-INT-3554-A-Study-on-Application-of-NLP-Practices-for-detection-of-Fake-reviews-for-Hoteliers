# %%
import os
os.chdir("C:/Users/ASUS/Desktop/Python Course/Datasets")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
prefly = pd.read_csv("flights.csv")
prefly
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4     2003        1955   2211.0
# 1        2008      1           3          4      754         735   1002.0
# 2        2008      1           3          4      628         620    804.0
# 3        2008      1           3          4     1829        1755   1959.0
# 4        2008      1           3          4     1940        1915   2121.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 1048570  2008      6          19          4     1551        1535   1923.0
# 1048571  2008      6          20          5     1555        1535   1927.0
# 1048572  2008      6          21          6     1555        1535   1917.0
# 1048573  2008      6          22          7     1607        1535   1941.0
# 1048574  2008      6          23          1     1608        1535   1933.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
prefly.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  1048575.0  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean      2008.0  3.385121e+00  1.542589e+01  3.993846e+00  1.519864e+03
# std          0.0  1.700650e+00  8.852621e+00  1.977002e+00  4.500644e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  2.000000e+00  8.000000e+00  2.000000e+00  1.203000e+03
# 50%       2008.0  3.000000e+00  1.500000e+01  4.000000e+00  1.546000e+03
# 75%       2008.0  5.000000e+00  2.300000e+01  6.000000e+00  1.902000e+03
# max       2008.0  6.000000e+00  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.048575e+06  1.044679e+06  1.048575e+06  1.048575e+06
# mean   1.468772e+03  1.610743e+03  1.632411e+03  2.220608e+03
# std    4.251120e+02  5.472327e+02  4.653917e+02  1.934374e+03
# ...

# %%
prefly.isnull().sum()
# Out:
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                3896
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   4
# ActualElapsedTime      3896
# CRSElapsedTime          157
# AirTime                3896
# ArrDelay               3896
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# TaxiIn                 3896
# TaxiOut                   0
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         362841
# WeatherDelay         362841
# NASDelay             362841
# SecurityDelay        362841
# LateAircraftDelay    362841
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
import numpy as np
flyframe = pd.DataFrame(prefly)
flyframe.iloc[:,[8,10,16,17,22]]=flyframe.iloc[:,[8,10,16,17,22]].apply(lambda x: x.fillna(x.value_counts().index[0]))
flyframe
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4     2003        1955   2211.0
# 1        2008      1           3          4      754         735   1002.0
# 2        2008      1           3          4      628         620    804.0
# 3        2008      1           3          4     1829        1755   1959.0
# 4        2008      1           3          4     1940        1915   2121.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 1048570  2008      6          19          4     1551        1535   1923.0
# 1048571  2008      6          20          5     1555        1535   1927.0
# 1048572  2008      6          21          6     1555        1535   1917.0
# 1048573  2008      6          22          7     1607        1535   1941.0
# 1048574  2008      6          23          1     1608        1535   1933.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
flyframe.isnull().sum()
# Out:
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                3896
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# TailNum                   0
# ActualElapsedTime      3896
# CRSElapsedTime          157
# AirTime                3896
# ArrDelay               3896
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# TaxiIn                 3896
# TaxiOut                   0
# Cancelled                 0
# CancellationCode          0
# Diverted                  0
# CarrierDelay         362841
# WeatherDelay         362841
# NASDelay             362841
# SecurityDelay        362841
# LateAircraftDelay    362841
# dtype: int64

# %%
flyframe.iloc[:,[0,1,2,3,4,5,6,7,9,11,12,13,14,15,18,19,20,21,23,24,25,26,27,28]]=flyframe.iloc[:,[0,1,2,3,4,5,6,7,9,11,12,13,14,15,18,19,20,21,23,24,25,26,27,28]].fillna(flyframe.iloc[:,[0,1,2,3,4,5,6,7,9,11,12,13,14,15,18,19,20,21,23,24,25,26,27,28]].mean())
flyframe
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4     2003        1955   2211.0
# 1        2008      1           3          4      754         735   1002.0
# 2        2008      1           3          4      628         620    804.0
# 3        2008      1           3          4     1829        1755   1959.0
# 4        2008      1           3          4     1940        1915   2121.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 1048570  2008      6          19          4     1551        1535   1923.0
# 1048571  2008      6          20          5     1555        1535   1927.0
# 1048572  2008      6          21          6     1555        1535   1917.0
# 1048573  2008      6          22          7     1607        1535   1941.0
# 1048574  2008      6          23          1     1608        1535   1933.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
flyframe.isnull().sum()
# Out:
# Year                 0
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# dtype: int64

# %%
flyframe.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  1048575.0  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean      2008.0  3.385121e+00  1.542589e+01  3.993846e+00  1.519864e+03
# std          0.0  1.700650e+00  8.852621e+00  1.977002e+00  4.500644e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  2.000000e+00  8.000000e+00  2.000000e+00  1.203000e+03
# 50%       2008.0  3.000000e+00  1.500000e+01  4.000000e+00  1.546000e+03
# 75%       2008.0  5.000000e+00  2.300000e+01  6.000000e+00  1.902000e+03
# max       2008.0  6.000000e+00  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.468772e+03  1.610743e+03  1.632411e+03  2.220608e+03
# std    4.251120e+02  5.462152e+02  4.653917e+02  1.934374e+03
# ...

# %%
flyframe.corr()
# Out:
#                    Year     Month  DayofMonth  DayOfWeek   DepTime  \
# Year                NaN       NaN         NaN        NaN       NaN
# Month               NaN  1.000000    0.020957   0.022139  0.025462
# DayofMonth          NaN  0.020957    1.000000  -0.021198  0.011964
# DayOfWeek           NaN  0.022139   -0.021198   1.000000  0.018711
# DepTime             NaN  0.025462    0.011964   0.018711  1.000000
# CRSDepTime          NaN  0.031677    0.012325   0.026140  0.884626
# ArrTime             NaN  0.005400    0.008353   0.010332  0.461435
# CRSArrTime          NaN  0.023018    0.010266   0.014525  0.717095
# FlightNum           NaN  0.003662   -0.001148  -0.013528 -0.026200
# ActualElapsedTime   NaN -0.017787   -0.003318   0.003884 -0.047771
# CRSElapsedTime      NaN -0.018523   -0.001647   0.008289 -0.045085
# AirTime             NaN -0.015089   -0.001849   0.007621 -0.052720
# ArrDelay            NaN -0.008045   -0.007086  -0.009428  0.132455
# ...

# %%
import seaborn as sns
sns.boxplot(x=flyframe['Year'])

# %%
sns.boxplot(x=flyframe['Month'])

# %%
sns.boxplot(x=flyframe['DepDelay'])

# %%
sns.boxplot(x=flyframe['ArrDelay'])

# %%
sns.boxplot(x=flyframe['AirTime'])

# %%
sns.boxplot(x=flyframe['TaxiIn'])

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(flyframe['DepDelay'],flyframe['ArrDelay'])
ax.set_xlabel('Departure')
ax.set_ylabel('Arrival')
plt.show()

# %%
Q1 = flyframe.quantile(0.25)
Q3 = flyframe.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                    0.000000
# Month                   3.000000
# DayofMonth             15.000000
# DayOfWeek               4.000000
# DepTime               699.000000
# CRSDepTime            685.000000
# ArrTime               713.000000
# CRSArrTime            690.000000
# FlightNum            2966.000000
# ActualElapsedTime      83.000000
# CRSElapsedTime         83.000000
# AirTime                78.000000
# ArrDelay               47.000000
# DepDelay               41.000000
# Distance              650.000000
# TaxiIn                  4.000000
# TaxiOut                11.000000
# Cancelled               0.000000
# Diverted                0.000000
# CarrierDelay           18.870359
# WeatherDelay            3.568032
# NASDelay               14.429618
# SecurityDelay           0.093284
# LateAircraftDelay      25.334310
# dtype: float64

# %%
print((flyframe<(Q1-1.5*IQR))|(flyframe>(Q3+1.5*IQR)))
# Out:
#          ActualElapsedTime  AirTime  ArrDelay  ArrTime  CRSArrTime  \
# 0                    False    False     False    False       False
# 1                    False    False     False    False       False
# 2                    False    False     False    False       False
# 3                    False    False     False    False       False
# 4                    False    False     False    False       False
# ...                    ...      ...       ...      ...         ...
# 1048570              False    False     False    False       False
# 1048571              False    False     False    False       False
# 1048572              False    False     False    False       False
# 1048573              False    False     False    False       False
# 1048574              False    False     False    False       False
#
#          CRSDepTime  CRSElapsedTime  CancellationCode  Cancelled  \
# 0             False           False             False      False
# ...

# %%
fly = flyframe[~((flyframe < (Q1 - 1.5*IQR))|(flyframe>(Q3+1.5*IQR))).any(axis=1)]
fly
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4     2003        1955   2211.0
# 1        2008      1           3          4      754         735   1002.0
# 2        2008      1           3          4      628         620    804.0
# 3        2008      1           3          4     1829        1755   1959.0
# 4        2008      1           3          4     1940        1915   2121.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 1048570  2008      6          19          4     1551        1535   1923.0
# 1048571  2008      6          20          5     1555        1535   1927.0
# 1048572  2008      6          21          6     1555        1535   1917.0
# 1048573  2008      6          22          7     1607        1535   1941.0
# 1048574  2008      6          23          1     1608        1535   1933.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
#1.Dep Delay vs ArrDelay
features1=fly.drop('DepDelay', axis=1)

# %%
features1
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4     2003        1955   2211.0
# 1        2008      1           3          4      754         735   1002.0
# 2        2008      1           3          4      628         620    804.0
# 3        2008      1           3          4     1829        1755   1959.0
# 4        2008      1           3          4     1940        1915   2121.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 1048570  2008      6          19          4     1551        1535   1923.0
# 1048571  2008      6          20          5     1555        1535   1927.0
# 1048572  2008      6          21          6     1555        1535   1917.0
# 1048573  2008      6          22          7     1607        1535   1941.0
# 1048574  2008      6          23          1     1608        1535   1933.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
labels1=fly["DepDelay"]
labels1
# Out:
# 0           8
# 1          19
# 2           8
# 3          34
# 4          25
#            ..
# 1048570    16
# 1048571    20
# 1048572    20
# 1048573    32
# 1048574    33
# Name: DepDelay, Length: 665266, dtype: int64

# %%
arrival = features1['ArrDelay']
dep = labels1
ax = plt.plot(arrival,dep,'o')
plt.ylabel("Departure")
plt.xlabel("Arrival")
# Out:
# Text(0.5, 0, 'Arrival')

# %%
fly.corr()
# Out:
#                    Year     Month  DayofMonth  DayOfWeek   DepTime  \
# Year                NaN       NaN         NaN        NaN       NaN
# Month               NaN  1.000000    0.021030   0.005700  0.011982
# DayofMonth          NaN  0.021030    1.000000  -0.019945  0.006821
# DayOfWeek           NaN  0.005700   -0.019945   1.000000  0.030771
# DepTime             NaN  0.011982    0.006821   0.030771  1.000000
# CRSDepTime          NaN  0.013027    0.007873   0.031021  0.997185
# ArrTime             NaN  0.004702    0.006284   0.030708  0.942186
# CRSArrTime          NaN  0.005775    0.007389   0.031450  0.938880
# FlightNum           NaN  0.018042    0.002444  -0.010358 -0.043833
# ActualElapsedTime   NaN -0.029740   -0.004796   0.000698 -0.085335
# CRSElapsedTime      NaN -0.031151   -0.004618   0.003883 -0.075777
# AirTime             NaN -0.024133   -0.005167   0.002682 -0.080583
# ArrDelay            NaN -0.011875   -0.014701  -0.007323  0.135283
# ...

# %%
mean_dep=dep.mean()

# %%
mean_dep
# Out:
# 22.71434734376926

# %%
ax = plt.plot(arrival,dep,'o')
plt.ylabel("Departure")
plt.xlabel("Arrival")
plt.axhline(mean_dep,color = 'r', linestyle ='-')
plt.show()

# %%
import statsmodels.api as sm
modelstats1 = sm.OLS(dep,arrival).fit()

# %%
summaryStats1=modelstats1.summary()

# %%
summaryStats1
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               DepDelay   R-squared (uncentered):                   0.840
# Model:                            OLS   Adj. R-squared (uncentered):              0.840
# Method:                 Least Squares   F-statistic:                          3.498e+06
# Date:                Fri, 12 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        23:29:21   Log-Likelihood:                     -2.5465e+06
# No. Observations:              665266   AIC:                                  5.093e+06
# Df Residuals:                  665265   BIC:                                  5.093e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#0 so we accept alt hyp

# %%
ax = plt.plot(arrival,dep,'o')
plt.ylabel("Departure")
plt.xlabel("Arrival")
plt.axhline(mean_dep,color = 'r', linestyle ='-')
sns.regplot(x="ArrDelay",y="DepDelay",data=fly)

# %%
X=arrival
y=dep

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4,random_state=1)#40% is for testing and 60% is for training
X_train
# Out:
# 115435     8.0
# 789186   -16.0
# 509232     0.0
# 90623     13.0
# 677494    99.0
#           ...
# 589512    22.0
# 767333    49.0
# 740496     9.0
# 768150     8.0
# 200968    57.0
# Name: ArrDelay, Length: 399159, dtype: float64

# %%
X_train.shape
# Out:
# (399159,)

# %%
X_train=X_train.values.reshape((-1,1))

# %%
from sklearn import linear_model as lm
modelLinearRegression1=lm.LinearRegression()
results=modelLinearRegression1.fit(X_train,y_train)
results
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
accuracy = modelLinearRegression1.score(X_train,y_train)
print("Accuracy of the model: ", accuracy)
# Out:
# Accuracy of the model:  0.6806775246557366

# %%
print('interception: ', modelLinearRegression1.intercept_)
print('slope: ', modelLinearRegression1.coef_)
# Out:
# interception:  9.139855561880236
# slope:  [0.73393399]

# %%
X_test = X_test.values.reshape((-1,1))

# %%
predections = modelLinearRegression1.predict(X_test)
plt.scatter(y_test,predections)

# %%
Xnew=[[80]]
ynew=modelLinearRegression1.predict(Xnew)
print("New ArrDelay: ", Xnew, " DepDelay: ", ynew)
# Out:
# New ArrDelay:  [[80]]  DepDelay:  [67.8545746]

# %%
from sklearn.metrics import mean_squared_error,r2_score
y_train_prediction=modelLinearRegression1.predict(X_train)
y_test_prediction=modelLinearRegression1.predict(X_test)

# %%
rmse_training_1 = (np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training_1 = r2_score(y_train,y_train_prediction)
print('RMSE is ',rmse_training_1) #We want this to be higher than the test
print('R2 score is ', r2_training_1)
rmse_test_1 = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_test_1 = r2_score(y_test,y_test_prediction)
print("\nRMSE test is ", rmse_test_1) #This has to be lower than the training
print("R2 test score is ", r2_test_1)
# Out:
# RMSE is  9.09912916370173
# R2 score is  0.6806775246557366
#
# RMSE test is  9.074134191671845
# R2 test score is  0.6786863755318282

# %%
#RMSE for testing is lower than the the RMSE for training which is good
#However, it is not good enough as R2 is so low

# %%
X=X.values.reshape(-1,1)
y_predicted=modelLinearRegression1.predict(X)

# %%
plt.plot(X,y_predicted, color='b')
plt.show()

# %%
#2. Second Group of 2 students --
#Arr Delay vs AirTime + DepDelay + TaxiIn
X=fly[["DepDelay","AirTime","TaxiIn"]]
y=fly["ArrDelay"]

# %%
modelstats2=sm.OLS(y,X).fit()
predictions=modelstats2.predict(X)
statsSummary2=modelstats2.summary()
statsSummary2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               ArrDelay   R-squared (uncentered):                   0.844
# Model:                            OLS   Adj. R-squared (uncentered):              0.844
# Method:                 Least Squares   F-statistic:                          1.199e+06
# Date:                Sat, 13 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        00:10:03   Log-Likelihood:                     -2.4902e+06
# No. Observations:              665266   AIC:                                  4.980e+06
# Df Residuals:                  665263   BIC:                                  4.980e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4,random_state=1)

# %%
X_train
# Out:
#         DepDelay  AirTime  TaxiIn
# 115435        14     63.0     6.0
# 789186        10    198.0     6.0
# 509232         6     93.0     5.0
# 90623         34    126.0     2.0
# 677494       103    120.0     8.0
# ...          ...      ...     ...
# 589512        19     66.0     5.0
# 767333        57    116.0     3.0
# 740496         9     41.0     3.0
# 768150         7     96.0     5.0
# 200968        64     61.0     3.0
#
# [399159 rows x 3 columns]

# %%
y_train
# Out:
# 115435     8.0
# 789186   -16.0
# 509232     0.0
# 90623     13.0
# 677494    99.0
#           ...
# 589512    22.0
# 767333    49.0
# 740496     9.0
# 768150     8.0
# 200968    57.0
# Name: ArrDelay, Length: 399159, dtype: float64

# %%
features = X_train.iloc[:,:].values

# %%
features
# Out:
# array([[ 14.,  63.,   6.],
#        [ 10., 198.,   6.],
#        [  6.,  93.,   5.],
#        ...,
#        [  9.,  41.,   3.],
#        [  7.,  96.,   5.],
#        [ 64.,  61.,   3.]])

# %%
labels = y_train.iloc[:].values

# %%
labels
# Out:
# array([  8., -16.,   0., ...,   9.,   8.,  57.])

# %%
X=features

# %%
y=labels

# %%
from sklearn import linear_model as lm
modelLinearRegression2=lm.LinearRegression()
results=modelLinearRegression2.fit(X,y)

# %%
predictions = modelLinearRegression2.predict(X)

# %%
accuracy=modelLinearRegression2.score(X,y)

# %%
print("Accuracy of the model: ", accuracy)
# Out:
# Accuracy of the model:  0.6885215400522217

# %%
#Evaluation and comparison of both models:
print("Model 2, Multiple Linear Regression -Arr Delay vs AirTime + DepDelay + TaxiIn-")
print('Slope for model: ', modelLinearRegression2.coef_)
print('Intercept: ', modelLinearRegression2.intercept_)
print("\n")

rmse=(np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)
print("The RMSE is: ", rmse)
print('The R2 score is: ', r2)
print("\n")
rmse_test_1 = (np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_test_1 = r2_score(y_test,y_test_prediction)
print("\nRMSE test is ", rmse_test_1) #This has to be lower than the training
print("R2 test score is ", r2_test_1)
# Out:
# Model 2, Multiple Linear Regression -Arr Delay vs AirTime + DepDelay + TaxiIn-
# Slope for model:  [ 0.9278448  -0.01160477  0.59390383]
# Intercept:  -4.867876580015611
#
#
# The RMSE is:  10.102126468253998
# The R2 score is:  0.6885215400522217
#
#
#
# RMSE test is  6.409096694656674
# R2 test score is  0.8740364341523854
